# %%
 '''
 Práctica 2 
 '''
    
#Bibliotecas
import numpy as np
from matplotlib import pyplot as plt
from scipy.fftpack import fft
from scipy.signal.windows import hann, gaussian, exponential, chebwin
from scipy import signal 
import os

# %%
def abre(path, file_name):
    data = np.loadtxt(path+file_name, delimiter='\t', dtype='str')
    data = data[:-1,:-1].T.astype('float') #Elimina la última fila y columna que no contienen nada
    
    return data

path = '/home/edu/Documentos/GitHub/MCIB-19-P-Edu/data/P1/' #Cambiar dependiendo de la compu
file = 'Apnea5.txt'


signals = abre(path,file)
signals1 = abre(path, 'Apnea3.txt')

PL = signals[0]
EKG = signals[1]
OX = signals[2]
EMG = signals[3]

PLext = signals1[0]
EKGext = signals1[1]
OXext = signals1[2]
EMGext = signals1[3]

plt.figure('EKG',figsize=(35,15))
plt.plot(EKG, 'm')
plt.grid()
plt.title('EKG', size=(55)).set_color(color='hotpink')

plt.figure('EMG', figsize=(35,15))
plt.title('EMG', size=(55)).set_color(color='teal')
plt.plot(EMG, 'b')
plt.grid()

plt.figure('OX', figsize=(35,15))
plt.title('OX', size=(55)).set_color(color='teal')
plt.plot(OX, color = 'orange')
plt.grid()

plt.figure('PL', figsize=(35,15))
plt.title('PL', size=(55)).set_color(color='teal')
plt.plot(PL, 'g')
plt.grid()

plt.show()

# %%
def dB(x):
    return 20*np.log10(np.abs(x))

# %%
'''
Primer punto de primer Actividad 
1.1 Usamos esas ventanas, porque son nuestras favoritas y son más fáciles de manipular y usar. 
En realidad fueron opciones aconsejadas por el Doctor. En las ventanas Gaussiana y Chebyshev,
se optó en la primera, una desviación estándar de 0.5 porque la dispersión de datos es pequeña 
y están mas cerca de la media; en la segunda opción se optó por los 100 dB de atenuación ya que 
nuestra Fs es de 200 Hz y no se puede ir más allá de ese valor.

'''
def compfft(signal):
    s_f = fft(signal) # obtención de la FFT de la señal original
    #1.1 Obtenemos las ventanas hanning, gaussiana, exponencial y chevy, con sus respectivos parámetros 
    wh = hann(signal.shape[0])
    wg = gaussian(signal.shape[0],0.5)
    we = exponential(signal.shape[0])
    wb = chebwin(signal.shape[0],100)
    #1.2 Se hizo la Multiplicación de la ventana diseñada en 1.1, por la señal original.
    Eh = wh*signal 
    Eg = wg*signal
    Ee = we*signal
    Eb = wb*signal
    # 1.3 Se convierten a Decibeles las FFT's de los resultados de 1.2
    Fh = dB(fft(Eh))
    Fg = dB(fft(Eg))
    Fe = dB(fft(Ee))
    Fb = dB(fft(Eb))
    # 1.4 Se Grafican las FFT's de 1.3 
    plt.figure('FFT',figsize=(18,10))
    plt.title('FFT', fontsize=40).set_color(color='white')
    plt.grid()
    # plt.plot(s_f[2:len(s_f)//2], 'k')
    plt.plot(Fh[2:len(Fh)//2], 'm')
    plt.plot(Fg[2:len(Fg)//2], 'b')
    plt.plot(Fe[2:len(Fe)//2], 'r')
    plt.plot(Fb[2:len(Fb)//2], 'g')
    plt.xlabel('Frecuencia en muestras', fontsize=40).set_color(color='white')
    plt.legend(['Hanning', 'Gaussian', 'Exponential', 'Chebyshev'])

# %%
# Se manda llamar la función para graficar la FFT de la ventana multiplicada por la señal 
# original
compfft(EKG)

# %%
'''
Segundo punto de la primera actividad
Estimación del PSD con el algoritmo de Welch

'''
def periodograma(signal, L, traslape):
    signal = list(signal) #Se hace que la señal de entrada sea una lista
    num = len(signal)//L #Se calcula cuantas veces se puede ventanear de manera entera
    T = int((1-traslape) * L) #Muestras de la ventana menos traslape
    temp = 0 #Mueve el slice
    temp1 = []#Guarda valores
    for s in range(num):
        p = signal[temp:temp+L] #Corrimiento de la señal
        temp1 += p #Se "appendiza" en temp
        temp += T #Se actualiza el corrimiento
    
    p = np.array(temp1).reshape(s+1,L) #Se le da nueva forma para que la señal quede en renglón
    p_f = fft(p).mean(axis=0) #Se saca la FFT de las señales y se calcula el prom coherente
    return dB(p_f) #Se regresa en dB

# %%
'''
Se llama a la función
'''
psd = periodograma(EKG, 2**12, .25)
plt.plot(psd[:psd.shape[0]//2],color='olive') #Graficamos la mitad de la señal
plt.grid()
plt.show()

# %%
# Tercer punto de pimer actividad Funcion para evaluar la respuesta en frecuencia de cualquier filtro
# diseñamos un filtro pasa banda butterworth de N orden y evaluamos su respuesta en frecuencia

def butterbp(cutoff, cutoff2, fs, order):
    Fc1 = np.array([cutoff, cutoff2])*2/fs
    b, a = signal.butter(order, Fc1 , btype='bandpass', analog=False)

    w, h = signal.freqz(b, a)
    fig = plt.figure()
    plt.title('Digital filter frequency response')
    ax1 = fig.add_subplot(111)

    plt.plot(w, 20 * np.log10(np.abs(h)), 'b')
    plt.ylabel('Amplitude [dB]', color='b')
    plt.xlabel('Frequency [rad/sample]')

    ax2 = ax1.twinx()
    angles = np.unwrap(np.angle(h))
    plt.plot( w,angles, 'g')
    plt.ylabel('Angle (radians)', color='g')
    plt.grid()
    plt.axis('tight')
    plt.show()
    
    return b, a

# %%
butterbp(9,90,200,3)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log10
#   del sys.path[0]
# (array([ 0.54535109,  0.        , -1.63605328,  0.        ,  1.63605328,
#          0.        , -0.54535109]),
#  array([ 1.        , -0.06299505, -1.8190133 ,  0.06149974,  1.24428322,
#         -0.01888095, -0.29715569]))

# %%
# creando el filtro desde cero dando valores a: a y b
sys1 = signal.lti(1, [1 / 100, 1]) # Creamos el sistema pasabajas primer orden
w, mag, phase = signal.bode(sys1) # Diagrama de bode: frecuencias, magnitud y fase
fig, axs= plt.subplots(2, 1, figsize=(10, 10))
axs[0].semilogx(w, mag) # Ejes logaritmicos
axs[1].semilogx(w, phase) 
axs[0].grid()
axs[1].grid()

# %%
#Cuarto punto PROMEDIO MÓVIL sin traslape, porque si le ponemos traslape solo hacemos que la
# señal se empiece a ir hacia arriba. A menos que hagas algo mega experto como Omar

def prommov(N, x):
    y_f = []
    for i in range(len(x)-N): #se resta N a len(x) para no llegar a un índice mayor al existente
        y_f.append(x[i+N] - (1/(1+N)) * sum(x[i+1:i+N+1]))

    return np.array(y_f)

# %%
EKG_PM = prommov(20,EKG)

plt.figure(figsize=(20,17))
plt.plot(EKG_PM)
plt.grid()
plt.show()

# %%
# Quinto punto de la primer actividad
# quitaremos tendencia de EKG punto numero 3 de actividad 2

def inversa(signal):
    y = signal
    x = np.arange(len(y))[:,np.newaxis]
    x0 = np.ones( (x.shape[0],1) )
    xf = np.concatenate( (x, x0), axis=1)
    w = np.dot( np.linalg.inv( np.dot( xf.T,xf ) ), np.dot( xf.T,y ) )
    return (w)
    
    
# corte de ventanas de la señal 
def corte(signal, L):
    t = np.arange(signal.shape[0]//L)*L
    #t = np.linspace(0,signal.shape[0],signal.shape[0]//L).astype('int')
    return t

# %%
c = corte(EKG,3000)
b = [EKG[i:i+3000] for i in c]
b = np.array(b)
b.shape
# Out:
# (6, 3000)

# %%
# Extracción de ventanas
v11 = b[0,:][:,np.newaxis]
v22 = b[1,:][:,np.newaxis]
v33 = b[2,:][:,np.newaxis]
v44 = b[3,:][:,np.newaxis]
v55 = b[4,:][:,np.newaxis]
v66 = b[5,:][:,np.newaxis]

# %%
v66.shape 
''' Sospecho que la adición del axis y el uso de .extend es lo que causa que sean 3
dimensiones'''
# Out:
# (3000, 1)

# %%
a = inversa(v11)
b = inversa(v22)
c = inversa(v33)
d = inversa(v44)
e = inversa(v55)
f = inversa(v66)

# %%
# W = [a b] 
# multiplicación de m punto a punto con la ventana respectiva
v1 = v11.T*(a[0])
v2 = v22.T*(b[0])
v3 = v33.T*(c[0])
v4 = v44.T*(d[0])
v5 = v55.T*(e[0])
v6 = v66.T*(e[0])

# %%
# Resta de b punto a punto con su ventana respectiva
v1 = v1+(a[1])
v2 = v2+(b[1])
v3 = v3+(c[1])
v4 = v4+(d[1])
v5 = v5+(e[1])
v6 = v6+(f[1])

# %%
# Resta de las ventanas, con la ventana original. 
v1b = v11.T-v1
v2b = v22.T-v2
v3b = v33.T-v3
v4b = v44.T-v4
v5b = v55.T-v5
v6b = v66.T-v6
x = []
x.extend([v1b,v2b,v3b,v4b,v5b,v6b])
x = np.array(x)

# %%
help( list.extend )
# Out:
# Help on method_descriptor:
#
# extend(...)
#     L.extend(iterable) -> None -- extend list by appending elements from the iterable

# %%
x.shape
# Out:
# (6, 1, 3000)

# %%
# Primer punto de segunda actividad 
# Estimar el espectro con FFT

fig, axs = plt.subplots (2, 2, figsize = (15,15))
axs[0, 0].plot( dB( fft( PL ) ) [:len(PL)//2] )
axs[0, 0].set_title('Espectro de Pletismografia').set_color(color='white')
axs[0, 1].plot( dB( fft( EKG ) ) [:len(EKG)//2], 'tab:orange')
axs[0, 1].set_title('Espectro de EKG').set_color(color='white')
axs[1, 0].plot( dB( fft( OX ) ) [:len(OX)//2], 'tab:green')
axs[1, 0].set_title('Espectro de Oximetria').set_color(color='white')
axs[1, 1].plot( dB( fft( EMG ) ) [:len(EMG)//2], 'tab:red')
axs[1, 1].set_title('Espectro de EMG').set_color(color='white')

# %%
L = 2**12

psd_PL = periodograma(PL,L,.75)
psd_EKG = periodograma(EKG,L,.75)
psd_OX = periodograma(OX,L,.75)
psd_EMG = periodograma(EMG,L,.75)

w = np.linspace(0,100,psd_PL.shape[0]//2)
W = np.linspace(0,100, dB(fft(PL)).shape[0]//2)

fig, axs = plt.subplots (2, 2, figsize = (15,15))
axs[0, 0].plot(w, psd_PL[:L//2] )
axs[0, 0].set_title('Espectro de Pletismografia').set_color(color='white')
axs[0, 1].plot(w, psd_EKG[:L//2], 'tab:orange')
axs[0, 1].set_title('Espectro de EKG').set_color(color='white')
axs[1, 0].plot(w, psd_OX[:L//2], 'tab:green')
axs[1, 0].set_title('Espectro de Oximetria').set_color(color='white')
axs[1, 1].plot(w, psd_EMG[:L//2], 'tab:red')
axs[1, 1].set_title('Espectro de EMG').set_color(color='white')

axs[0, 0].plot(W, dB( fft( PL ) ) [:len(PL)//2], 'tab:red' )
axs[0, 0].set_title('Espectro de Pletismografia').set_color(color='white')
axs[0, 1].plot(W, dB( fft( EKG ) ) [:len(EKG)//2], 'tab:blue')
axs[0, 1].set_title('Espectro de EKG').set_color(color='white')
axs[1, 0].plot(W, dB( fft( OX ) ) [:len(OX)//2], 'tab:orange')
axs[1, 0].set_title('Espectro de Oximetria').set_color(color='white')
axs[1, 1].plot(W, dB( fft( EMG ) ) [:len(EMG)//2], 'tab:green')
axs[1, 1].set_title('Espectro de EMG').set_color(color='white')


'''
Para todas las gráficas se tienen que quitar las bajas frecuencias
'''
# Out:
# '\nPara todas las gráficas se tienen que quitar las bajas frecuencias\n'

# %%
# Punto número dos de la actividad dos 
#Se va a filtrar el Oxi, Pletis, EMG y EKG con un filtro Butter pasa altas y pasa banda, orden 3
b1, a1 = butterbp(0.1, 30, 200, 3) #Este filtro se va a usar para el EKG
b2, a2 = butterbp(5,90,200, 3) #Para el resto de las señales 
b3, a3 = butterbp(0.5,10,200, 3)

EKG1 = signal.lfilter(b1,a1,EKG)
PLET1 = signal.lfilter(b3, a3, PL)
OXI1 = signal.lfilter(b2, a2, OX)
EMG1 = signal.lfilter(b2, a2, EMG)

# graficamos las señales filtradas 
fig, axs = plt.subplots (4, 1, figsize = (20,15))
axs[0].plot(EKG1)
axs[0].set_title('Electrocardiograma').set_color(color='white')
axs[1].plot(PLET1[800:] , 'tab:orange')
axs[1].set_title('Pletismografía').set_color(color='white')
axs[2].plot(OXI1, 'tab:green')
axs[2].set_title('Oximetría').set_color(color='white')
axs[3].plot(EMG1[1:], 'tab:red')
axs[3].set_title('Electromiografía').set_color(color='white')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':

# %%
np.savez_compressed( '/home/edu/Documentos/GitHub/MCIB-19-P-Edu/data/P2/filtrados' ,EKG=EKG1, EMG=EMG1, PLET=PLET1, OXI=OXI1, )
