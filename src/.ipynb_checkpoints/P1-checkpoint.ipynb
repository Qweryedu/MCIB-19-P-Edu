# %%
'''
Código de El Edu para abrir archivos, una parte se está tomando de los conocimientos previos del
Dr. Omar Piña
Sorry, not sorry
19/9/19
'''

import numpy as np
import matplotlib.pyplot as plt

def abre(path, file_name):
    data = np.loadtxt(path+file_name, delimiter='\t', dtype='str')
    data = data[:-1]
    
    return data

path = '/home/eduardo/GitKraken/MetodosComp/MCIB-19-P-Edu/data/P1/'
file = 'Apnea1.txt'


signal = abre(path,file)

for i in range(signal.shape[1]):
    plt.figure(figsize=(20,15))b
    plt.plot(signal[:200,i].astype('float'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-29958cea575a> in <module>
#      23 for i in range(signal.shape[1]):
#      24     plt.figure(figsize=(20,15))
# ---> 25     plt.plot(signal[:200,i].astype('float'))
#      26 plt.show()
#
# ValueError: could not convert string to float:

# %%
for s in signal[:,:-1].T:
    plt.figure( figsize=(10,4) )
    plt.plot( s[:200].astype('float') )

plt.show()

# %%
s[:200].astype('float').shape
# Out:
# (200,)
