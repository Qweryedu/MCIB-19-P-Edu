# %%
'''
Interpolación
28/10/19
'''

#Bibliotecas
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
'''
Simulando datos
'''

x = np.arange( 6 )[:,np.newaxis]
y = np.random.randint( -5,5, ( x.shape[0], 1 ) )

plt.figure( figsize=(10,8) )
plt.plot( x, y, 'o', markersize=12, color='deeppink' )
plt.grid()
plt.show()

# %%
def ones_ext(X):
    X_ext = np.concatenate( (X, np.ones((X.shape[0],1)) ), axis=1 )
    return X_ext.copy()

def pinv(X,y):
    w = np.linalg.inv( np.dot( X.T,X ) )
    w = np.dot( w, X.T )
    w = np.dot( w, y )
    
    return w

# %%
m = pinv( ones_ext(x), y )
ys = np.dot( ones_ext(x), m )

plt.plot( x, y, 'o', markersize=12, color='deeppink' )
plt.plot( x, ys, '-', linewidth=3, color='rebeccapurple' )
plt.grid()
plt.show()

# %%
G = 5

y = np.array([1,1,1,1,0,0])
x_tst = np.linspace( [1E-6], [5], 100 )

x_ext = np.concatenate( tuple( x**i for i in range(1,G+1) )[::-1], axis=1 )

x_tst = np.concatenate( tuple( x_tst**i for i in range(1,G+1) )[::-1], axis=1 )

w = pinv( ones_ext(x_ext), y )
ys = np.dot( ones_ext(x_tst), w )

plt.figure(  figsize=(12,4) )
plt.plot( x, y, 'o', markersize=12, color='deeppink' )
plt.plot( x_tst[:,-1], ys.flatten() , 'g.', linewidth=3, color='rebeccapurple' )
plt.xticks(size=10,color='w')
plt.yticks(size=10,color='w')
plt.grid()
plt.show()

# %%
w
# Out:
# array([ 0.03333333, -0.375     ,  1.41666667, -2.125     ,  1.05      ,
#         1.        ])

# %%
import wfdb
#Registro de EMG de Physionet
path = os.path.abspath( '../../data/Clase' )
fname = '/e0103'
data = wfdb.rdsamp( path+fname )

samp = 5000
sr = data[1]['fs']
data = data[0][:samp:,0]
shape = data.shape[0]
t = np.linspace( 0,shape/sr, shape )



plt.figure( figsize=(12,4) )
plt.plot( t, data, color='c' )
plt.grid()
plt.figure( figsize=(12,4) )
plt.psd( data, Fs=sr, NFFT=2**10, color='blue' )
plt.show()
print(sr)
# Out:
# 250

# %%
sub = 4
data_sub = data[::sub]
t_sub = t[::sub]
sr_sub = sr/sub

plt.figure( figsize=(12,4) )
plt.plot( t, data, color='m' )
plt.plot( t_sub, data_sub, '.-', color='teal' )
plt.grid()

plt.figure( figsize=(12,4) )
plt.psd( data, Fs=sr, NFFT=2**10, color='hotpink' )
plt.psd( data_sub, Fs=sr_sub, NFFT=2**10, color='aquamarine' )
plt.grid()
plt.show()

# %%
from scipy import interpolate

interp = interpolate.interp1d( t_sub, data_sub, kind='linear' )

sr = 4000
t = np.linspace( 0, t_sub[-1], t_sub[-1]*sr )

y = interp(t)

# %%
limit = 100
k = 70
plt.figure( figsize=(20,8) )
plt.plot(  t_sub[:limit], data_sub[:limit], '.', color='k' )
plt.plot( t[:int(limit*k)], y[:int(limit*k)], color='firebrick' )
plt.grid()
plt.show()

# %%
'''Clase del 11/11/19'''
import wfdb
#Registro de EMG de Physionet
path = os.path.abspath( '../../data/Clase' )
fname = '/e0103'
data = wfdb.rdsamp( path+fname )

samp = 5000
sr = data[1]['fs']
data = data[0][:samp]
shape = data.shape[0]
t = np.linspace( 0,shape/sr, shape )

tmp = np.random.normal( 0, .2, samp )[:, np.newaxis]
data = np.concatenate( (data, tmp), axis=1 )

plt.figure( figsize=(12,4) )
plt.plot( t, data[:,0], color='green' )
plt.plot( t, data[:,1], color='blue' )
plt.plot( t, data[:,2], color='tomato' )
plt.grid()
plt.show()
print( sr )
# Out:
# 250

# %%
data.shape
# Out:
# (5000, 3)

# %%
M = np.array( [[2, .5, -.1],
              [.2, 2.9, .3],
              [-.4, -.2, 1.8]
              ])
data_mix = np.dot( data, M)

# %%
plt.figure( figsize=(12,4))
plt.plot ( t , data [:,2],     color='k', label='original')
plt.plot ( t , data_mix [:,2], color='red', label='mix')
plt.legend(loc='best')
plt.xticks( color='w' )
plt.yticks( color='w' )
plt.grid(True)

# %%
M_inv = np.linalg.inv( M )
data_x = data - data.mean(axis=0)
data_rec = np.dot (data_x, M_inv)


plt.figure( figsize=(12,4))
plt.plot ( t , data [:,0],     color='k', label='original')
plt.plot ( t , data_mix [:,0], color='red', label='mix')
plt.plot ( t, data_rec [:,0], color='blue', label='recreada')
plt.legend(loc='best')
plt.xticks( color='w' )
plt.yticks( color='w' )
plt.grid(True)

# %%
from sklearn.decomposition import PCA as pca

# %%
model_pca =  pca(svd_solver='full', whiten=True)
model_pca.fit( data_mix)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='full', tol=0.0, whiten=True)

# %%
data_pca = model_pca.inverse_transform( data_mix)

# %%
plt.figure( figsize=(15,8) )
plt.plot( data_pca[:,1], color='red')
plt.plot( data_mix[:,1], color='k')
plt.plot( data [:,1], color='blue')
plt.grid(True)

# %%
import scipy.io.wavfile as waves

# %%
path = os.path.abspath( '../../data/Clase' )
sonido_cat = '/cane2.wav'
sonido_omg = '/spwo1.wav'
sonido_ang = '/talk.wav'
muestreo1, sonido1 = waves.read(path+sonido_cat)
muestreo2, sonido2 = waves.read(path+sonido_omg)
muestreo3, sonido3 = waves.read(path+sonido_ang)

matriz = np.concatenate( (sonido1[:11611][:,np.newaxis], sonido2[:11611][:,np.newaxis],
                          sonido3[:11611][:,np.newaxis]), axis=1 )
mix = np.dot(matriz,M)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
sd.play( sonido1, samplerate=muestreo1 )

# %%
model_pca1 =  pca(svd_solver='full', whiten=True)
model_pca1.fit( mix )
data_pca1 = model_pca1.inverse_transform(mix)

# %%
plt.figure( figsize=(15,8) )
plt.plot( data_pca1[:,1], color='red')
plt.plot( data_pca1[:,0], '_b' )
plt.plot( data_pca1[:,2], 'g' )
#plt.plot( mix[:,2], color='k')
#plt.plot( matriz [:,2], color='yellow')
plt.xticks(color='w')
plt.yticks( color='w' )
plt.grid(True)

# %%
import sounddevice as sd
audio = data_pca1.astype(np.int16)

plt.figure( figsize=(15,8) )
plt.plot( audio[:,0]*.0005, 'b' )
#plt.plot( audio[:,1], color='red')
#plt.plot( audio[:,2], 'g' )

plt.xticks(color='w')
plt.yticks( color='w' )
plt.grid(True)

# %%
sd.play( audio*.00005, samplerate=8000 )

# %%
help( sd.play )
# Out:
# Help on function play in module sounddevice:
#
# play(data, samplerate=None, mapping=None, blocking=False, loop=False, **kwargs)
#     Play back a NumPy array containing audio data.
#
#     This is a convenience function for interactive use and for small
#     scripts.  It cannot be used for multiple overlapping playbacks.
#
#     This function does the following steps internally:
#
#     * Call `stop()` to terminate any currently running invocation
#       of `play()`, `rec()` and `playrec()`.
#
#     * Create an `OutputStream` and a callback function for taking care
#       of the actual playback.
#
#     * Start the stream.
#
#     * If ``blocking=True`` was given, wait until playback is done.
#       If not, return immediately.
#
#     If you need more control (e.g. block-wise gapless playback, multiple
#     overlapping playbacks, ...), you should explicitly create an
#     `OutputStream` yourself.
#     If NumPy is not available, you can use a `RawOutputStream`.
#
# ...

# %%
''' 
Clase del 12/11/19
ICA
Idependent Component Anlysis
x = As ... ESTIMA LA MATRIZ A.

'''
# Out:
# ' \nClase del 12/11/19\nICA\nIdependent Component Anlysis\nx = As ... ESTIMA LA MATRIZ A.\n\n'
