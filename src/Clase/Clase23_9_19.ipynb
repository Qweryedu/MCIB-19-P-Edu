# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#Decalaracion de constantes
sr = 320 #Frecuencia de muestreo
L = 5 #segundos
F = []

F.append(5)
F.append(30)

# %%
t = np.linspace(0,L,L*sr)[:,np.newaxhelp(signal)is]

F = np.array(F)[np.newaxis]

# %%
p = (2*np.pi*t*F) 
p = np.sin(p) 
p = p.sum(axis=1) + 2

# %%
plt.figure(figsize=(20,5))
plt.plot(p[:300], color='teal', linewidth=4)
plt.plot(-y_f[:300], 'm', linewidth=4)
#plt.plot(y_ff[:300], color='orange', linewidth=4)
plt.grid()

# %%
from scipy import signal

b,a = signal.butter(4, 2/sr*15,btype='high' )

y_f = signal.lfilter(b,a,p)
y_ff = signal.lfilter(b,a,p[::-1])[::-1]

# %%
N = 40
b = signal.firwin(40, 2/sr*15)
y_f = signal.lfilter(b,[1], p)

# %%
def prommov(N, x):
  y_f = []
  for i in range(len(x)-N):
   y_f.append(x[i+N] - (1/(1+N)) * sum(x[i+1:i+N+1]))

  return np.array(y_f)

# %%
'''
Código de Omar en clase /Incompleto
'''

def mmovi(x, n=21, N=20):
  t = x[n-N+1:n+1].mean()
  return x[n] - t


for i in

# %%
y_f = prommov(25,p)
